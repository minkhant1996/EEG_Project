# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import mne
from mne import io
from mne import read_epochs
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

# %%
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:1

# %%
class CNN(nn.Module):
    def __init__(self,input_dim,hidden_dim, num_layers, num_classes, bidirectional, dropout):
        super(CNN, self).__init__()
        
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers

        #Layer 0
        self.layer0 = nn.BatchNorm1d(32)
        
        #Layer 1
        self.layer1 = nn.Sequential(nn.BatchNorm1d(32),
                    nn.Conv1d(in_channels= 32, out_channels= 16, kernel_size = 1, stride=1),
                    nn.Tanh())
        
        #Layer2
        self.layer2 = nn.Sequential(nn.BatchNorm1d(16),
                    nn.Conv1d(in_channels= 16, out_channels= 16 , kernel_size = 20, stride = 20),
                    nn.Tanh())
        
        # layer 3, lstm
        self.lstm = nn.LSTM(16, hidden_dim, num_layers, bidirectional=bidirectional, dropout=dropout, batch_first=True)
        
        # layer 4, fc
        self.fc1 = nn.Linear(hidden_dim * num_layers, 1) #hidden_dim * num_layers
       # self.fc2 = nn.Linear(128, 128)
        #self.fc3 = nn.Linear(128, 1)
        self.dropout = nn.Dropout(dropout)
        
        self.sigmoid = nn.Sigmoid()
        self.softmax = nn.Softmax()
        
        
        
#         #Layer3
#         self.fc1 = nn.Sequential(
#                     nn.Flatten(),
#                     nn.Linear( 16 * round(self.input_samples/ 20), 128),
#                     nn.Tanh(),
#                     nn.Dropout(p=0.8))
#         #Layer4
#         self.fc2 = nn.Sequential(
#                     nn.Linear(128 , 128),
#                     nn.Tanh(),
#                     nn.Dropout(p=0.8))
        
#         #Layer5
#         self.fc3 = nn.Sequential(nn.Linear(128 , num_classes),nn.Sigmoid())
    
    
    def forward(self, x):
        
#         x = x.unsqueeze(0)
#         x = x.permute(1, 3, 0, 2)
        x = self.layer0(x)
        x = self.layer1(x)
        x = self.dropout(x)
        x = self.layer2(x)
        x = self.dropout(x)
        x = x.permute(0, 2, 1)
        h0 = torch.zeros(self.num_layers * 2, x.size(0), self.hidden_dim).to(device)
        c0 = torch.zeros(self.num_layers * 2, x.size(0), self.hidden_dim).to(device)
        
        out,_ = self.lstm(x, (h0, c0))
        out = self.fc1(out[:, -1, :])
        out = self.dropout(out)
       # out = self.fc2(out)
      #  out = self.dropout(out)
        #out = self.fc3(out)
       # out = self.dropout(out)
        out = self.sigmoid(out)
        return out

# %%
learning_rate=0.001
epoches = 50
input_dim = 32
hidden_dim = 128
num_layers = 2
num_classes =2
bidirectional = True
dropout = 0.2

# %%
def train(model, iterator, optimizer, criterion):
    total = 0
    correct = 0
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    
    for batch, labels in iterator:
        
        #Move tensors to the configured device
        batch = batch.to(device)
        labels = labels.to(device)
        
        #Forward pass
        outputs = model(batch.float())
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
                
        #check accuracy
        predictions = model(batch.float())
       # print("predictions",predictions)
        #print("labels", labels)
        predicted = predictions.round()
#         print("train predicted",predicted)
#         _, predicted = torch.max(predictions.data, 1) 
        #returns max value, indices
#         predicted = predicted.unsqueeze(1)
        total += labels.size(0)  #keep track of total
#         correct += (predicted == labels).sum().item()  #.item() give the raw number
        correct += (predicted == labels).sum().item()
#         print("label",labels.size())
#         print("predicted", predicted.size())
#         print("correct", correct)
#         print("total", total)
#         print("acc", correct/ total)
        acc = 100 * (correct / total)
                
        epoch_loss += loss.item()
        epoch_acc = acc
        
    return epoch_loss / len(iterator), epoch_acc, predicted

def evaluate(model, iterator, criterion):
    
    total = 0
    correct = 0
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
    
        for batch, labels in iterator:
            
            #Move tensors to the configured device
            batch = batch.to(device)
            labels = labels.to(device)

            predictions = model(batch.float())
            loss = criterion(predictions, labels)

#             _, predicted = torch.max(predictions.data, 1)  #returns max value, indices
            predicted = predictions.round()
            # print("test predicted",predicted.T)
#             predicted = predicted.unsqueeze(1)
            
            total += labels.size(0)  #keep track of total
            correct += (predicted == labels).sum().item()  #.item() give the raw number
            acc = 100 * (correct / total)
            
            epoch_loss += loss.item()
            epoch_acc += acc
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator) , predicted

# %%
import time

def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
from sklearn.model_selection import train_test_split


X = np.load('X_pool.npy')
y = np.load('y_pool.npy')
print("X.shape: ", X.shape)
print("y.shape: ", y.shape)
# Out:
# X.shape:  (34236, 32, 410)
# y.shape:  (34236,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 27)
print("X_train shape: ", X_train.shape)
print("X_test shape: ", X_test.shape)
print("y_train.shape: ", y_train.shape)
print("y_test.shape: ", y_test.shape)
# Out:
# X_train shape:  (27388, 32, 410)
# X_test shape:  (6848, 32, 410)
# y_train.shape:  (27388,)
# y_test.shape:  (6848,)

# %%
train_acc_list = []
val_acc_list = []
subject_no_list = []
        
X = torch.Tensor(X_train)
y = torch.Tensor(y_train)
y = y-1
y = y.unsqueeze(1)
#         print(X.size())
#         print(y.size())

X_val = torch.Tensor(X_test)
y_val = torch.Tensor(y_test)
y_val = y_val-1
y_val = y_val.unsqueeze(1)
#         print(X_val.size())
#         print(y_val.size())

train_ds = TensorDataset(X, y)
valid_ds = TensorDataset(X_val, y_val)
       
BATCH_SIZE= 64

train_iterator = torch.utils.data.DataLoader(dataset=train_ds, batch_size=BATCH_SIZE, shuffle=True)
valid_iterator = torch.utils.data.DataLoader(dataset=valid_ds, batch_size=BATCH_SIZE, shuffle=False)

learning_rate=0.001
epoches = 50

model = CNN(input_dim, hidden_dim, num_layers, num_classes, bidirectional, dropout).to(device)
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
print(model)

N_EPOCHS = 50

best_valid_loss = float('inf')

train_losses = []
valid_losses = []

train_accs = []
valid_accs = []

train_predicted_labels = []
valid_predicted_labels = []

train_true_labels = []
valid_true_labels = []

# for i, model in enumerate(models):
#     print(f"Training {type(model).__name__}")

#     start_time = time.time()

for epoch in range(N_EPOCHS):
    start_time = time.time()

    train_loss, train_acc, predicted_train = train(model, train_iterator, optimizer, criterion)
    valid_loss, valid_acc, predicted_eval = evaluate(model, valid_iterator, criterion)

    train_losses.append(train_loss); train_accs.append(train_acc); train_predicted_labels.append(predicted_train)
    valid_losses.append(valid_loss); valid_accs.append(valid_acc); valid_predicted_labels.append(predicted_eval)

    end_time = time.time()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)

    if (epoch+1) % 1 == 0:
        print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
        print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc:.2f}%')
        print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc:.2f}%')

#         print(predicted_train)
#         print(predicted_eval)

    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss

# to save in excel
train_acc_list.append(train_acc)
val_acc_list.append(valid_acc)

#to plot
fig,ax = plt.subplots(2,1,sharex=True,figsize=(10,10))
ax[0].plot(np.arange(N_EPOCHS),train_losses,label = "train loss")
ax[0].plot(np.arange(N_EPOCHS),valid_losses, label = "valid loss")
ax[1].plot(np.arange(N_EPOCHS),train_accs,label = "train acc")
ax[1].plot(np.arange(N_EPOCHS),valid_accs,label = "valid acc")

plt.subplots_adjust(hspace=0.03)
ax[1].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")
ax[1].set_ylabel("Accuracy")
ax[0].legend()
ax[1].legend()
ax[0].grid(True)
ax[1].grid(True)
plt.show()
# Out:
# CNN(
#   (layer0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Conv1d(32, 16, kernel_size=(1,), stride=(1,))
#     (2): Tanh()
#   )
#   (layer2): Sequential(
#     (0): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Conv1d(16, 16, kernel_size=(20,), stride=(20,))
#     (2): Tanh()
#   )
#   (lstm): LSTM(16, 128, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (fc1): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (sigmoid): Sigmoid()
#   (softmax): Softmax(dim=None)
# )
# Epoch: 01 | Epoch Time: 0m 14s
# 	Train Loss: 0.501 | Train Acc: 83.34%
# 	 Val. Loss: 0.438 |  Val. Acc: 83.07%
# Epoch: 02 | Epoch Time: 0m 8s
# 	Train Loss: 0.481 | Train Acc: 83.35%
# 	 Val. Loss: 0.437 |  Val. Acc: 83.07%
# Epoch: 03 | Epoch Time: 0m 9s
# 	Train Loss: 0.475 | Train Acc: 83.40%
# 	 Val. Loss: 0.430 |  Val. Acc: 83.10%
# Epoch: 04 | Epoch Time: 0m 9s
# 	Train Loss: 0.476 | Train Acc: 83.40%
# 	 Val. Loss: 0.431 |  Val. Acc: 83.08%
# Epoch: 05 | Epoch Time: 0m 9s
# 	Train Loss: 0.474 | Train Acc: 83.44%
# 	 Val. Loss: 0.429 |  Val. Acc: 83.01%
# Epoch: 06 | Epoch Time: 0m 9s
# 	Train Loss: 0.471 | Train Acc: 83.49%
# 	 Val. Loss: 0.424 |  Val. Acc: 83.29%
# Epoch: 07 | Epoch Time: 0m 9s
# 	Train Loss: 0.467 | Train Acc: 83.55%
# 	 Val. Loss: 0.423 |  Val. Acc: 83.50%
# Epoch: 08 | Epoch Time: 0m 8s
# 	Train Loss: 0.468 | Train Acc: 83.60%
# 	 Val. Loss: 0.421 |  Val. Acc: 83.34%
# Epoch: 09 | Epoch Time: 0m 11s
# 	Train Loss: 0.465 | Train Acc: 83.70%
# 	 Val. Loss: 0.424 |  Val. Acc: 83.42%
# Epoch: 10 | Epoch Time: 0m 8s
# 	Train Loss: 0.463 | Train Acc: 83.85%
# 	 Val. Loss: 0.423 |  Val. Acc: 83.77%
# Epoch: 11 | Epoch Time: 0m 8s
# 	Train Loss: 0.458 | Train Acc: 83.97%
# 	 Val. Loss: 0.421 |  Val. Acc: 84.01%
# Epoch: 12 | Epoch Time: 0m 9s
# 	Train Loss: 0.460 | Train Acc: 84.10%
# 	 Val. Loss: 0.419 |  Val. Acc: 83.78%
# Epoch: 13 | Epoch Time: 0m 11s
# 	Train Loss: 0.456 | Train Acc: 84.22%
# 	 Val. Loss: 0.414 |  Val. Acc: 83.58%
# Epoch: 14 | Epoch Time: 0m 12s
# 	Train Loss: 0.455 | Train Acc: 84.30%
# 	 Val. Loss: 0.411 |  Val. Acc: 83.68%
# Epoch: 15 | Epoch Time: 0m 12s
# 	Train Loss: 0.456 | Train Acc: 84.37%
# 	 Val. Loss: 0.417 |  Val. Acc: 84.18%
# Epoch: 36 | Epoch Time: 0m 9s
# 	Train Loss: 0.421 | Train Acc: 85.47%
# 	 Val. Loss: 0.400 |  Val. Acc: 84.81%
# Epoch: 37 | Epoch Time: 0m 8s
# 	Train Loss: 0.420 | Train Acc: 85.50%
# 	 Val. Loss: 0.413 |  Val. Acc: 84.26%
# Epoch: 38 | Epoch Time: 0m 6s
# 	Train Loss: 0.419 | Train Acc: 85.64%
# 	 Val. Loss: 0.419 |  Val. Acc: 83.65%
# Epoch: 39 | Epoch Time: 0m 6s
# 	Train Loss: 0.420 | Train Acc: 85.99%
# 	 Val. Loss: 0.392 |  Val. Acc: 84.97%
# Epoch: 40 | Epoch Time: 0m 6s
# 	Train Loss: 0.416 | Train Acc: 85.94%
# 	 Val. Loss: 0.397 |  Val. Acc: 84.05%
# Epoch: 41 | Epoch Time: 0m 6s
# 	Train Loss: 0.414 | Train Acc: 85.91%
# 	 Val. Loss: 0.412 |  Val. Acc: 83.56%
# Epoch: 42 | Epoch Time: 0m 6s
# 	Train Loss: 0.412 | Train Acc: 86.22%
# 	 Val. Loss: 0.409 |  Val. Acc: 84.72%
# Epoch: 43 | Epoch Time: 0m 6s
# 	Train Loss: 0.412 | Train Acc: 86.21%
# 	 Val. Loss: 0.416 |  Val. Acc: 83.89%
# Epoch: 44 | Epoch Time: 0m 6s
# 	Train Loss: 0.409 | Train Acc: 86.38%
# 	 Val. Loss: 0.410 |  Val. Acc: 84.60%
# Epoch: 45 | Epoch Time: 0m 7s
# 	Train Loss: 0.406 | Train Acc: 86.36%
# 	 Val. Loss: 0.397 |  Val. Acc: 84.41%
# Epoch: 46 | Epoch Time: 0m 7s
# 	Train Loss: 0.404 | Train Acc: 86.45%
# 	 Val. Loss: 0.397 |  Val. Acc: 84.68%
# Epoch: 47 | Epoch Time: 0m 6s
# 	Train Loss: 0.403 | Train Acc: 86.53%
# 	 Val. Loss: 0.419 |  Val. Acc: 83.71%
# Epoch: 48 | Epoch Time: 0m 8s
# 	Train Loss: 0.401 | Train Acc: 86.63%
# 	 Val. Loss: 0.445 |  Val. Acc: 83.20%
# Epoch: 49 | Epoch Time: 0m 10s
# 	Train Loss: 0.399 | Train Acc: 86.55%
# 	 Val. Loss: 0.403 |  Val. Acc: 84.39%
# Epoch: 50 | Epoch Time: 0m 9s
# 	Train Loss: 0.395 | Train Acc: 86.83%
# 	 Val. Loss: 0.407 |  Val. Acc: 84.54%

# %%
num_parameters = sum(p.numel() for p in model.parameters())
print("Total number of parameters in CNN Conv2d model is {}".format(num_parameters))
# Out:
# Total number of parameters in CNN Conv2d model is 550849

# %% [markdown]
# ## Save accuracy for both train and val in excel

# %%
# import xlsxwriter

# workbook = xlsxwriter.Workbook('BN3 Conv1D+LSTM ACC.xlsx')
# worksheet = workbook.add_worksheet()

# worksheet.write(0, 0, 'Subject No')
# worksheet.write(0, 1, 'Train Accuracy')
# worksheet.write(0, 2, 'Val Accuracy')

# for i in range(len(train_acc_list)):
#     worksheet.write(i+1, 0, subject_no_list[i])
#     worksheet.write(i+1, 1, train_acc_list[i]) 
#     worksheet.write(i+1, 2, val_acc_list[i])
    
# workbook.close()
